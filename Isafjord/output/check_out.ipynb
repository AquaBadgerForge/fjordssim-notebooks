# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np

# %%
ds = xr.open_dataset('C:/Users/fisa/Documents/Isafjord/output/snapshots_ocean.nc')
# Out:
# C:\Users\fisa\AppData\Local\Temp\ipykernel_18276\1374687089.py:1: FutureWarning: In a future version, xarray will not decode the variable 'time' into a timedelta64 dtype based on the presence of a timedelta-like 'units' attribute by default. Instead it will rely on the presence of a timedelta64 'dtype' attribute, which is now xarray's default way of encoding timedelta64 values.
# To continue decoding into a timedelta64 dtype, either set `decode_timedelta=True` when opening this dataset, or add the attribute `dtype='timedelta64[ns]'` to this variable on disk.
# To opt-in to future behavior, set `decode_timedelta=False`.
#   ds = xr.open_dataset('C:/Users/fisa/Documents/Isafjord/output/snapshots_ocean.nc')

# %%
ds
# Out:
# <xarray.Dataset> Size: 43GB
# Dimensions:               (φ_aca: 210, λ_caa: 256, z_aac: 28, z_aaf: 29,
#                            φ_afa: 211, λ_faa: 257, time: 1795)
# Coordinates:
#   * φ_aca                 (φ_aca) float32 840B 65.76 65.76 65.76 ... 66.18 66.18
#   * λ_caa                 (λ_caa) float32 1kB -23.32 -23.32 ... -22.3 -22.3
#   * z_aac                 (z_aac) float32 112B -155.0 -145.0 ... -1.5 -0.75
#   * z_aaf                 (z_aaf) float32 116B -160.0 -150.0 ... -1.0 -0.5
#   * φ_afa                 (φ_afa) float32 844B 65.76 65.76 65.76 ... 66.18 66.18
#   * λ_faa                 (λ_faa) float32 1kB -23.32 -23.32 ... -22.3 -22.3
#   * time                  (time) timedelta64[ns] 14kB 00:00:00 ... 224 days 0...
# Data variables: (12/23)
#     bottom_height         (φ_aca, λ_caa) float32 215kB ...
#     peripheral_nodes_ccc  (z_aac, φ_aca, λ_caa) float32 6MB ...
#     peripheral_nodes_ccf  (z_aaf, φ_aca, λ_caa) float32 6MB ...
# ...

# %%
ds.Δx_fca.values.mean()
# Out:
# np.float32(181.12762)

# %%
data = ds.u.isel(time=-1, z_aac=27).values
data = np.ma.masked_where(data == 0, data)

# %%
plt.contourf(data)
plt.colorbar()

# %%
ds.T.isel(time=-1, z_aac=0).min()
# Out:
# <xarray.DataArray 'T' ()> Size: 4B
# array(0., dtype=float32)
# Coordinates:
#     time     timedelta64[ns] 8B 52 days
#     z_aac    float32 4B 0.5
